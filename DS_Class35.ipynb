# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("customer_data.csv")
data
# Out:
#          ID  Building  Year of sale  Month of sale Type of property  \
# 0    1030.0       1.0        2005.0           11.0        Apartment
# 1    1029.0       1.0        2005.0           10.0        Apartment
# 2    2002.0       2.0        2007.0            7.0        Apartment
# 3    2031.0       2.0        2007.0           12.0        Apartment
# 4    1049.0       1.0        2004.0           11.0        Apartment
# ..      ...       ...           ...            ...              ...
# 263  5047.0       5.0           NaN            NaN        Apartment
# 264  5048.0       5.0           NaN            NaN        Apartment
# 265  5050.0       5.0           NaN            NaN        Apartment
# 266  5051.0       5.0           NaN            NaN        Apartment
# 267     NaN       NaN           NaN            NaN              NaN
#
#      Property #  Area (ft.)      Price  Status  Unnamed: 9  ...       Y     M  \
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Building', 'Year of sale', 'Month of sale', 'Type of property',
#        'Property #', 'Area (ft.)', 'Price', 'Status', 'Unnamed: 9',
#        'Customer ID', 'Entity', 'Name', 'Surname', 'Age at time of purchase',
#        'Interval', 'Y', 'M', 'D', 'Gender', 'Country', 'State', 'Purpose',
#        'Deal satisfaction', 'Mortgage', 'Source'],
#       dtype='object')

# %%
del data["Unnamed: 9"]

# %%
data
# Out:
#          ID  Building  Year of sale  Month of sale Type of property  \
# 0    1030.0       1.0        2005.0           11.0        Apartment
# 1    1029.0       1.0        2005.0           10.0        Apartment
# 2    2002.0       2.0        2007.0            7.0        Apartment
# 3    2031.0       2.0        2007.0           12.0        Apartment
# 4    1049.0       1.0        2004.0           11.0        Apartment
# ..      ...       ...           ...            ...              ...
# 263  5047.0       5.0           NaN            NaN        Apartment
# 264  5048.0       5.0           NaN            NaN        Apartment
# 265  5050.0       5.0           NaN            NaN        Apartment
# 266  5051.0       5.0           NaN            NaN        Apartment
# 267     NaN       NaN           NaN            NaN              NaN
#
#      Property #  Area (ft.)      Price  Status Customer ID  ...       Y     M  \
# ...

# %%
data["Gender"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 263     True
# 264     True
# 265     True
# 266     True
# 267     True
# Name: Gender, Length: 268, dtype: bool

# %%
data["Gender"].fillna("Firm",inplace=True)

# %%
data["Gender"]
# Out:
# 0         F
# 1         F
# 2         M
# 3         M
# 4         F
#        ...
# 263    Firm
# 264    Firm
# 265    Firm
# 266    Firm
# 267    Firm
# Name: Gender, Length: 268, dtype: object

# %%
data["Gender"].value_counts()
# Out:
# M       108
# Firm     90
# F        70
# Name: Gender, dtype: int64

# %%
customers = pd.read_csv("customers.csv")

# %%
customers
# Out:
#     Customer ID      Entity        Name   Surname Age at time of purchase  \
# 0         C0028  Individual     Madalyn    Mercer                      19
# 1         C0027  Individual        Lara  Carrillo                      22
# 2         C0112  Individual     Donavan   Flowers                      22
# 3         C0160  Individual      Darien    Dorsey                      22
# 4         C0014  Individual  Alessandra     Perry                      25
# ..          ...         ...         ...       ...                     ...
# 191       C0174        Firm     Marleez        Co                     NaN
# 192       C0174        Firm     Marleez        Co                     NaN
# 193       C0174        Firm     Marleez        Co                     NaN
# 194       C0174        Firm     Marleez        Co                     NaN
# 195       C0174        Firm     Marleez        Co                     NaN
#
#     Interval       Y     M     D Gender Country       State     Purpose  \
# ...

# %%
customers["Gender"].fillna("Firms", inplace=True)

# %%
customers
# Out:
#     Customer ID      Entity        Name   Surname Age at time of purchase  \
# 0         C0028  Individual     Madalyn    Mercer                      19
# 1         C0027  Individual        Lara  Carrillo                      22
# 2         C0112  Individual     Donavan   Flowers                      22
# 3         C0160  Individual      Darien    Dorsey                      22
# 4         C0014  Individual  Alessandra     Perry                      25
# ..          ...         ...         ...       ...                     ...
# 191       C0174        Firm     Marleez        Co                     NaN
# 192       C0174        Firm     Marleez        Co                     NaN
# 193       C0174        Firm     Marleez        Co                     NaN
# 194       C0174        Firm     Marleez        Co                     NaN
# 195       C0174        Firm     Marleez        Co                     NaN
#
#     Interval       Y     M     D Gender Country       State     Purpose  \
# ...

# %%
customers["Gender"]
# Out:
# 0          F
# 1          F
# 2          M
# 3          M
# 4          F
#        ...
# 191    Firms
# 192    Firms
# 193    Firms
# 194    Firms
# 195    Firms
# Name: Gender, Length: 196, dtype: object

# %%
customers["Gender"].value_counts()
# Out:
# M        108
# F         70
# Firms     18
# Name: Gender, dtype: int64

# %%
plt.pie(customers["Gender"].value_counts(),colors=["orange","green","red"],autopct="%1.2f%%",labels=["Males","Females","Firms"])
plt.show()

# %%
#data["Age at time of purchase"].fillna()

# %%
#np.average(data[""])

# %%
#plt.scatter(data["Age at time of purchase"],data["Price"])
